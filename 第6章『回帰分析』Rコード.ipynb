# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#第6章『回帰分析』" data-toc-modified-id="第6章『回帰分析』-1">第6章『回帰分析』</a></span><ul class="toc-item"><li><span><a href="#p.1" data-toc-modified-id="p.1-1.1">p.1</a></span></li><li><span><a href="#p.4" data-toc-modified-id="p.4-1.2">p.4</a></span></li><li><span><a href="#p.5" data-toc-modified-id="p.5-1.3">p.5</a></span></li><li><span><a href="#p.8" data-toc-modified-id="p.8-1.4">p.8</a></span></li><li><span><a href="#p.11" data-toc-modified-id="p.11-1.5">p.11</a></span></li><li><span><a href="#p.12" data-toc-modified-id="p.12-1.6">p.12</a></span></li><li><span><a href="#p.20" data-toc-modified-id="p.20-1.7">p.20</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 第6章『回帰分析』

# %% [markdown]
# ## p.1

# %%
#help(mtcars)

# %% [markdown]
# ## p.4

# %%
(kaiki1 <- lm(mpg~disp, data=mtcars))
# Out:
# Call:
# lm(formula = mpg ~ disp, data = mtcars)
#
# Coefficients:
# (Intercept)         disp
#    29.59985     -0.04122

# %%
kaiki1 <- lm(mpg~disp, data=mtcars)
kaiki1
# Out:
# Call:
# lm(formula = mpg ~ disp, data = mtcars)
#
# Coefficients:
# (Intercept)         disp
#    29.59985     -0.04122

# %%
plot(mpg~disp, data=mtcars)
abline(kaiki1)
# Out:
# plot without title

# %% [markdown]
# ## p.5

# %%
predict(kaiki1, data.frame(disp=100.0))
# Out:
#        1
# 25.47834

# %% [markdown]
# ## p.8

# %%
(kaiki2 <- lm(mpg~disp+cyl, data=mtcars))
# Out:
# Call:
# lm(formula = mpg ~ disp + cyl, data = mtcars)
#
# Coefficients:
# (Intercept)         disp          cyl
#    34.66099     -0.02058     -1.58728

# %%
kaiki2 <- lm(mpg~disp+cyl, data=mtcars)
kaiki2
# Out:
# Call:
# lm(formula = mpg ~ disp + cyl, data = mtcars)
#
# Coefficients:
# (Intercept)         disp          cyl
#    34.66099     -0.02058     -1.58728

# %%
summary(kaiki2)
# Out:
# Call:
# lm(formula = mpg ~ disp + cyl, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4213 -2.1722 -0.6362  1.1899  7.0516
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.66099    2.54700  13.609 4.02e-14 ***
# disp        -0.02058    0.01026  -2.007   0.0542 .
# cyl         -1.58728    0.71184  -2.230   0.0337 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.055 on 29 degrees of freedom
# Multiple R-squared:  0.7596,	Adjusted R-squared:  0.743
# F-statistic: 45.81 on 2 and 29 DF,  p-value: 1.058e-09

# %%
kaiki2$fitted
# Out:
#           Mazda RX4       Mazda RX4 Wag          Datsun 710      Hornet 4 Drive
#            21.84395            21.84395            26.08886            19.82676
#   Hornet Sportabout             Valiant          Duster 360           Merc 240D
#            14.55267            20.50602            14.55267            25.29227
#            Merc 230            Merc 280           Merc 280C          Merc 450SE
#            25.41371            21.68752            21.68752            16.28581
#          Merc 450SL         Merc 450SLC  Cadillac Fleetwood Lincoln Continental
#            16.28581            16.28581            12.24731            12.49431
#   Chrysler Imperial            Fiat 128         Honda Civic      Toyota Corolla
#            12.90598            26.69196            26.75371            26.84839
#       Toyota Corona    Dodge Challenger         AMC Javelin          Camaro Z28
#            25.83979            15.41718            15.70536            14.75851
#    Pontiac Firebird           Fiat X1-9       Porsche 914-2        Lotus Europa
#            13.72933            26.68578            25.83568            26.35438
#      Ford Pantera L        Ferrari Dino       Maserati Bora          Volvo 142E
#            14.73792            22.15271            15.76711            25.82127

# %%
kaiki2$residuals
# Out:
#           Mazda RX4       Mazda RX4 Wag          Datsun 710      Hornet 4 Drive
#         -0.84395255         -0.84395255         -3.28885510          1.57324352
#   Hornet Sportabout             Valiant          Duster 360           Merc 240D
#          4.14732774         -2.40601638         -0.25267226         -0.89226849
#            Merc 230            Merc 280           Merc 280C          Merc 450SE
#         -2.61371193         -2.48751693         -3.88751693          0.11418581
#          Merc 450SL         Merc 450SLC  Cadillac Fleetwood Lincoln Continental
#          1.01418581         -1.08581419         -1.84730532         -2.09430892
#   Chrysler Imperial            Fiat 128         Honda Civic      Toyota Corolla
#          1.79401841          5.70804444          3.64629354          7.05160883
#       Toyota Corona    Dodge Challenger         AMC Javelin          Camaro Z28
#         -4.33979314          0.08281514         -0.50535572         -1.45850859
#    Pontiac Firebird           Fiat X1-9       Porsche 914-2        Lotus Europa
#          5.47067308          0.61421953          0.16432359          4.04561603
#      Ford Pantera L        Ferrari Dino       Maserati Bora          Volvo 142E
#          1.06207504         -2.45270705         -0.76710662         -4.42126787

# %%
cor(mtcars$mpg, kaiki2$fitted)
# Out:
# [1] 0.8715307

# %%
plot(mtcars$mpg, kaiki2$fitted)
# Out:
# plot without title

# %%
predict(kaiki2, data.frame(disp=300.0, cyl=8))
# Out:
#        1
# 15.78769

# %% [markdown]
# ## p.11

# %%
hist(kaiki1$residuals)
# Out:
# Plot with title “Histogram of kaiki1$residuals”

# %%
hist(kaiki2$residuals)
# Out:
# Plot with title “Histogram of kaiki2$residuals”

# %%
summary(kaiki2)
# Out:
# Call:
# lm(formula = mpg ~ disp + cyl, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4213 -2.1722 -0.6362  1.1899  7.0516
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.66099    2.54700  13.609 4.02e-14 ***
# disp        -0.02058    0.01026  -2.007   0.0542 .
# cyl         -1.58728    0.71184  -2.230   0.0337 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.055 on 29 degrees of freedom
# Multiple R-squared:  0.7596,	Adjusted R-squared:  0.743
# F-statistic: 45.81 on 2 and 29 DF,  p-value: 1.058e-09

# %% [markdown]
# ## p.12

# %%
confint(kaiki2, level=0.95)
# Out:
#             2.5 %       97.5 %
# (Intercept) 29.45178692 39.8702025668
# disp        -0.04156253  0.0003952592
# cyl         -3.04316181 -0.1313918048

# %%
summary(kaiki2)
# Out:
# Call:
# lm(formula = mpg ~ disp + cyl, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4213 -2.1722 -0.6362  1.1899  7.0516
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.66099    2.54700  13.609 4.02e-14 ***
# disp        -0.02058    0.01026  -2.007   0.0542 .
# cyl         -1.58728    0.71184  -2.230   0.0337 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.055 on 29 degrees of freedom
# Multiple R-squared:  0.7596,	Adjusted R-squared:  0.743
# F-statistic: 45.81 on 2 and 29 DF,  p-value: 1.058e-09

# %% [markdown]
# ## p.20

# %%
AIC(kaiki1)
# Out:
# [1] 170.2094

# %%
AIC(kaiki2)
# Out:
# [1] 167.1456
